# %%
import pandas as pd
from urllib.parse import urlencode
import requests
from requests import Response
import plotly.graph_objects as go
import sqlalchemy
from datetime import datetime, date, time
import os, sys
import datetime as dt
from dateutil.relativedelta import relativedelta
from math import ceil
import numpy as np

# %%
# sys.path.append(os.path.abspath('.'))

# %%
import foward_test_valuation_strategy as common

# %%
keys = ['total equity', 'gross profit', 'total assets']

# list_stock_link = 'https://trading.vcsc.com.vn/restapi/api/v1/market/stock/listed?marketType=HOSE&securitiesType=ALL&fetchCount=1000'
# hose_list = pd.DataFrame(common.get_rest(url=list_stock_link, body={}))
# hose_list['len'] = hose_list['code'].apply(lambda x: len(x))
# hose_list = hose_list[hose_list['len'] == 3].code.tolist()

hose_list = ['AAA','AMD','ANV','APG','ASM','AST','BCG','BID','BMP','BWE','CCL','CII','CMG','CRE','CSV','CTD','CTF',
             'CTG','CTI','CVT','D2D','DAG','DBC','DBD','DCL','DCM','DGW','DHC','DHG','DIG','DLG','DPG','DPM','DRC',
             'DRH','DXG','EIB','FCN','FIR','FIT','FLC','FPT','FRT','FTS','GAS','GEG','GEX','GIL','GMD','HAG','HAI',
             'HAX','HBC','HCM','HDB','HDC','HDG','HHS','HII','HNG','HPG','HPX','HQC','HSG','HT1','HVH','HVN','IBC',
             'IDI','IJC','IMP','ITA','JVC','KBC','KDH','KOS','KSB','LCG','LDG','LHG','MBB','MSH','MSN','MWG','NCT',
             'NKG','NLG','NT2','NTL','NVL','OGC','PC1','PDR','PHC','PHR','PLX','PME','PNJ','POW','PPC','PTB','PVD',
             'PVT','REE','ROS','SAB','SAM','SBT','SCR','SHI','SKG','SMB','SSI','STB','STK','SZC','SZL','TCB','TCH',
             'TCM','TDH','TDM','TLG','TNA','TNI','TPB','TTB','TVB','VCB','VCI','VGC','VHC','VHM','VIC','VJC','VND',
             'VNG','VNM','VPB','VPG','VPI','VRE','VSC']

# %%
len(hose_list)
# Out:
# 143

# %%
magic1_universe = pd.read_csv('magic1-universe.csv')['code'].to_list()

# %%
lst_type = common.get_group_market_cap(date= '2021-04-29', lst_code=hose_list)

# %% [markdown]
# # If you don't have finincial_data.csv, run this code.

# %%
access_tok = common.login()
# Out:
# POST REQUEST - url=http://172.31.240.7:3000/api/v1/login, body={'grant_type': 'password_tradex', 'client_id': 'tradex-admin', 'client_secret': 'tradex-admin', 'username': 'vinh.do@techx.vn', 'password': '123456'}
# ...

# %%
data = pd.DataFrame()
for key in keys:
    for year in range(2014, 2022):
        for quarter in range(1, 5):
            df = common.query_financial_data(year=year, 
                                             quarter=quarter, 
                                             list_stock=hose_list, 
                                             type=key, 
                                             access_token=access_tok)
            if len(df) > 0:
                df = pd.melt(df, id_vars=['code', 'quarter', 'year'], value_vars=key)
            data = pd.concat([data, df])
            print('KEY: {} ====== YEAR: {} ===== QUAR: {}'.format(key, year, quarter))
    print('DONEEEEEEE')
data
# Out:
# KEY: total equity ====== YEAR: 2014 ===== QUAR: 1
# KEY: total equity ====== YEAR: 2014 ===== QUAR: 2
# KEY: total equity ====== YEAR: 2014 ===== QUAR: 3
# KEY: total equity ====== YEAR: 2014 ===== QUAR: 4
# KEY: total equity ====== YEAR: 2015 ===== QUAR: 1
# KEY: total equity ====== YEAR: 2015 ===== QUAR: 2
# KEY: total equity ====== YEAR: 2015 ===== QUAR: 3
# KEY: total equity ====== YEAR: 2015 ===== QUAR: 4
# KEY: total equity ====== YEAR: 2016 ===== QUAR: 1
# KEY: total equity ====== YEAR: 2016 ===== QUAR: 2
# KEY: total equity ====== YEAR: 2016 ===== QUAR: 3
# KEY: total equity ====== YEAR: 2016 ===== QUAR: 4
# KEY: total equity ====== YEAR: 2017 ===== QUAR: 1
# KEY: total equity ====== YEAR: 2017 ===== QUAR: 2
# KEY: total equity ====== YEAR: 2017 ===== QUAR: 3
# KEY: total equity ====== YEAR: 2017 ===== QUAR: 4
# KEY: total equity ====== YEAR: 2018 ===== QUAR: 1
# KEY: total equity ====== YEAR: 2018 ===== QUAR: 2
# KEY: total equity ====== YEAR: 2018 ===== QUAR: 3
# ...

# %%
data.to_csv('financial_data_magic_3.csv', index=None)

# %%
data
# Out:
#    code quarter  year      variable     value
# 0   CTI       1  2014  total equity    177051
# 1   HDB       1  2014  total equity   8626692
# 2   AAA       1  2014  total equity    558110
# 3   AMD       1  2014  total equity    308824
# 4   ANV       1  2014  total equity   1362760
# ..  ...     ...   ...           ...       ...
# 54  AMD       2  2021  total assets   2713796
# 55  AST       2  2021  total assets    567021
# 56  FPT       2  2021  total assets  46980501
# 57  HAX       2  2021  total assets   1270796
# 58  HHS       2  2021  total assets   4022635
#
# [11655 rows x 5 columns]

# %% [markdown]
# # START HEREEEE

# %%
data = pd.read_csv('financial_data_magic_3.csv')

# %%
data = data.reset_index(drop=True)

# %%
equity = data[data['variable']=='total equity']
assets = data[data['variable']=='total assets']
grossProfit = data[data['variable']=='gross profit']

# %%
equity = equity.drop(columns=['variable']).rename(columns={'value':'total equity'})
assets = assets.drop(columns=['variable']).rename(columns={'value':'total assets'})
grossProfit = grossProfit.drop(columns=['variable']).rename(columns={'value':'gross profit'})

# %%
equity['yrQ'] = equity['year'].apply(lambda x: str(x)) + equity['quarter'].apply(lambda x: str(x))
assets['yrQ'] = assets['year'].apply(lambda x: str(x)) + assets['quarter'].apply(lambda x: str(x))
# grossProfit['yrQ'] = grossProfit['year'].apply(lambda x: str(x)) + grossProfit['quarter'].apply(lambda x: str(x))

# %%
equity_pivot = pd.pivot(equity, index='yrQ', columns='code', values='total equity')
assets_pivot = pd.pivot(assets, index='yrQ', columns='code', values='total assets')
# grossProfit_pivot = pd.pivot(grossProfit, index='yrQ', columns='code', values='gross profit')

# %%
equity_pivot = equity_pivot.fillna(method='ffill')
assets_pivot = assets_pivot.fillna(method='ffill')

# %%
equity_pivot_melted = pd.melt(equity_pivot.reset_index(), id_vars=['yrQ'], value_vars=equity_pivot.columns, value_name='total equity')
assets_pivot_melted = pd.melt(assets_pivot.reset_index(), id_vars=['yrQ'], value_vars=assets_pivot.columns, value_name='total assets')

# %%
equity_pivot_melted['year'] = equity_pivot_melted['yrQ'].apply(lambda x: int(x[:4]))
equity_pivot_melted['quarter'] = equity_pivot_melted['yrQ'].apply(lambda x: int(x[4:]))
assets_pivot_melted['year'] = assets_pivot_melted['yrQ'].apply(lambda x: int(x[:4]))
assets_pivot_melted['quarter'] = assets_pivot_melted['yrQ'].apply(lambda x: int(x[4:]))

# %%
equity = equity_pivot_melted[['code', 'year', 'quarter', 'total equity']]
assets = assets_pivot_melted[['code', 'year', 'quarter', 'total assets']]

# %%
data = pd.merge(equity, grossProfit, on=['code', 'quarter', 'year'], how='outer')
data = pd.merge(data, assets, on=['code', 'quarter', 'year'], how='outer')

# %%
data = data.sort_values(by=['code', 'year', 'quarter']).reset_index(drop=True)

# %%
data
# Out:
#      code  year  quarter  total equity  gross profit  total assets
# 0     AAA  2014        1      558110.0       44348.0     1067787.0
# 1     AAA  2014        2      565521.0       48442.0     1103569.0
# 2     AAA  2014        3      561728.0       51291.0     1142601.0
# 3     AAA  2014        4      776937.0       38664.0     1421651.0
# 4     AAA  2015        1      781399.0       27720.0     1413882.0
# ...   ...   ...      ...           ...           ...           ...
# 4285  VSC  2020        2     2185842.0       94864.0     2477001.0
# 4286  VSC  2020        3     2175866.0      109779.0     2467881.0
# 4287  VSC  2020        4     2170698.0      134355.0     2458144.0
# 4288  VSC  2021        1     2245100.0      118780.0     2521244.0
# 4289  VSC  2021        2     2245100.0           NaN     2521244.0
#
# [4290 rows x 6 columns]

# %%
price = common.get_stock_price(stock_arr=hose_list, 
                               to_date='2021-07-29', 
                               from_date='2015-01-01', pivot_type=False, price=True)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     691     def do_execute(self, cursor, statement, parameters, context=None):
# --> 692         cursor.execute(statement, parameters)
#     693
#
# ~\anaconda3\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     205         assert isinstance(query, (bytes, bytearray))
# --> 206         res = self._query(query)
#     207         return res
#
# ...

# %%
volume = common.get_stock_volume(stock_arr=hose_list, 
                               to_date='2021-07-01', 
                               from_date='2015-01-01', pivot_type=False, price=True)

# %%
oi = common.get_stock_oi(stock_arr=hose_list, to_date='2021-07-29', from_date='2015-01-01', pivot_type=False)

# %%
len(hose_list)
# Out:
# 143

# %%
price_oi = pd.merge(price, oi, on=['date', 'code'], how='left')
price_vol = pd.merge(price, volume, on=['date', 'code'], how='left')

# %%
price_oi['marcap'] = price_oi['close'] * 1000 * price_oi['oi']
price_vol['value'] = price_vol['close'] * 1000 * price_vol['volume']

# %%
price_oi['date'] = price_oi['date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))
price_vol['date'] = price_vol['date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
price_oi['month'] = price_oi['date'].dt.month
price_vol['month'] = price_vol['date'].dt.month

# %%
price_oi.loc[(price_oi['month']!=price_oi['month'].shift(-1))|(
                price_oi['code']!=price_oi['code'].shift(-1)), 'choose'] = 1
price_oi_monthly = price_oi[price_oi['choose']==1].reset_index(drop=True).drop(columns=['choose', 'month'])

price_vol.loc[(price_vol['month']!=price_vol['month'].shift(-1))|(
                price_vol['code']!=price_vol['code'].shift(-1)), 'choose'] = 1
price_vol_monthly = price_vol[price_vol['choose']==1].reset_index(drop=True).drop(columns=['choose', 'month'])

# %%
price_vol_monthly_pivot = pd.pivot(price_vol_monthly, index='date', columns='code', values='value')
price_avg_value_monthly = price_vol_monthly_pivot.rolling(6).mean()

# %%
price_avg_value_monthly['avg'] = price_avg_value_monthly.mean(axis=1)

# %%
price_vol_monthly[price_vol_monthly['code']=='AAA']
# Out:
#          date code  close     volume         value
# 0  2015-01-30  AAA   5.94    426.300  2.532222e+06
# 1  2015-02-27  AAA   6.22    759.296  4.722821e+06
# 2  2015-03-31  AAA   5.76     66.800  3.847680e+05
# 3  2015-04-27  AAA   5.94    168.900  1.003266e+06
# 4  2015-05-29  AAA   6.08    112.600  6.846080e+05
# ..        ...  ...    ...        ...           ...
# 74 2021-03-31  AAA  16.60   2755.000  4.573300e+07
# 75 2021-04-29  AAA  16.45   2520.300  4.145894e+07
# 76 2021-05-31  AAA  15.25   2402.100  3.663202e+07
# 77 2021-06-30  AAA  19.50  13771.700  2.685482e+08
# 78 2021-07-01  AAA  19.45  10794.000  2.099433e+08
#
# [79 rows x 5 columns]

# %%
price_avg_value_monthly
# Out:
# code                 AAA           AMD           ANV           APG  \
# date
# 2015-01-30           NaN           NaN           NaN           NaN
# 2015-02-27           NaN           NaN           NaN           NaN
# 2015-03-31           NaN           NaN           NaN           NaN
# 2015-04-27           NaN           NaN           NaN           NaN
# 2015-05-29           NaN           NaN           NaN           NaN
# ...                  ...           ...           ...           ...
# 2021-03-31  3.712166e+07  1.451368e+07  1.089859e+07  8.694157e+06
# 2021-04-29  4.216291e+07  2.608943e+07  1.118212e+07  8.782719e+06
# 2021-05-31  3.484403e+07  2.867191e+07  1.042500e+07  1.118924e+07
# 2021-06-30  7.444611e+07  2.882606e+07  8.830439e+06  1.048036e+07
# 2021-07-01  1.042440e+08  2.788616e+07  1.448022e+07  1.509265e+07
#
# code                 ASM           AST           BCG           BID  \
# date
# 2015-01-30           NaN           NaN           NaN           NaN
# ...

# %%
price_avg_value_monthly=price_avg_value_monthly[price_avg_value_monthly>200000]
price_avg_value_monthly[price_avg_value_monthly>200000]=1

# %%
# for x in price_avg_value_monthly.columns[:-1]:
#     price_avg_value_monthly[x] = price_avg_value_monthly[x] / price_avg_value_monthly['avg']

# price_avg_value_monthly

# %%
# price_avg_value_monthly=price_avg_value_monthly[price_avg_value_monthly>0.25]
# price_avg_value_monthly[price_avg_value_monthly>0.25]=1

# price_avg_value_monthly = price_avg_value_monthly.dropna(how='all')

# %%
# price_avg_value_monthly['count'] = price_avg_value_monthly.count(axis=1) -1 

# price_avg_value_monthly

# %%
# price_avg_value_monthly = price_avg_value_monthly.drop(columns=['avg', 'count'])
# price_avg_value_monthly

# %%
price_oi_monthly
# Out:
#             date code  close         oi        marcap
# 0     2015-01-30  AAA   5.94  39.599998  2.352240e+05
# 1     2015-02-27  AAA   6.22  39.599998  2.463120e+05
# 2     2015-03-31  AAA   5.76  39.599998  2.280960e+05
# 3     2015-04-27  AAA   5.94  39.599998  2.352240e+05
# 4     2015-05-29  AAA   6.08  39.599998  2.407680e+05
# ...          ...  ...    ...        ...           ...
# 10023 2021-03-31  VSC  53.56  55.122799  2.952377e+06
# 10024 2021-04-29  VSC  49.50  55.122799  2.728579e+06
# 10025 2021-05-31  VSC  51.70  55.122799  2.849849e+06
# 10026 2021-06-30  VSC  60.00  55.122799  3.307368e+06
# 10027 2021-07-01  VSC  59.60  55.122799  3.285319e+06
#
# [10028 rows x 5 columns]

# %%
price_oi_monthly = pd.merge(price_oi_monthly, lst_type, on=['code'], how='left')

# %%
price_oi_monthly
# Out:
#             date code  close         oi        marcap    type
# 0     2015-01-30  AAA   5.94  39.599998  2.352240e+05  midCap
# 1     2015-02-27  AAA   6.22  39.599998  2.463120e+05  midCap
# 2     2015-03-31  AAA   5.76  39.599998  2.280960e+05  midCap
# 3     2015-04-27  AAA   5.94  39.599998  2.352240e+05  midCap
# 4     2015-05-29  AAA   6.08  39.599998  2.407680e+05  midCap
# ...          ...  ...    ...        ...           ...     ...
# 10023 2021-03-31  VSC  53.56  55.122799  2.952377e+06  midCap
# 10024 2021-04-29  VSC  49.50  55.122799  2.728579e+06  midCap
# 10025 2021-05-31  VSC  51.70  55.122799  2.849849e+06  midCap
# 10026 2021-06-30  VSC  60.00  55.122799  3.307368e+06  midCap
# 10027 2021-07-01  VSC  59.60  55.122799  3.285319e+06  midCap
#
# [10028 rows x 6 columns]

# %%
price_oi_monthly['date_lag_x'] = price_oi_monthly['date'].apply(lambda x: x-relativedelta(months=5))
price_oi_monthly['year'] = price_oi_monthly['date_lag_x'].dt.year
price_oi_monthly['quarter'] = price_oi_monthly['date_lag_x'].dt.month.apply(lambda x: ceil(x/3))
price_oi_monthly
# Out:
#             date code  close         oi        marcap    type date_lag_x  \
# 0     2015-01-30  AAA   5.94  39.599998  2.352240e+05  midCap 2014-08-30
# 1     2015-02-27  AAA   6.22  39.599998  2.463120e+05  midCap 2014-09-27
# 2     2015-03-31  AAA   5.76  39.599998  2.280960e+05  midCap 2014-10-31
# 3     2015-04-27  AAA   5.94  39.599998  2.352240e+05  midCap 2014-11-27
# 4     2015-05-29  AAA   6.08  39.599998  2.407680e+05  midCap 2014-12-29
# ...          ...  ...    ...        ...           ...     ...        ...
# 10023 2021-03-31  VSC  53.56  55.122799  2.952377e+06  midCap 2020-10-31
# 10024 2021-04-29  VSC  49.50  55.122799  2.728579e+06  midCap 2020-11-29
# 10025 2021-05-31  VSC  51.70  55.122799  2.849849e+06  midCap 2020-12-31
# 10026 2021-06-30  VSC  60.00  55.122799  3.307368e+06  midCap 2021-01-30
# 10027 2021-07-01  VSC  59.60  55.122799  3.285319e+06  midCap 2021-02-01
#
#        year  quarter
# 0      2014        3
# 1      2014        3
# 2      2014        4
# ...

# %%
price_oi_fin_monthly = pd.merge(price_oi_monthly, data, on=['code', 'year', 'quarter'])

# %%
price_oi_fin_monthly['pB'] = price_oi_fin_monthly['total equity'] / price_oi_fin_monthly['marcap']

price_oi_fin_monthly['grossProfit/assets']=price_oi_fin_monthly['gross profit']/price_oi_fin_monthly['total assets']

# %%
price_oi_fin_monthly['year-quarter'] = price_oi_fin_monthly['year'].apply(lambda x: str(x)) + (
                                                                price_oi_fin_monthly['quarter'].apply(lambda x: str(x)))

# %%
price_oi_fin_monthly
# Out:
#             date code  close         oi        marcap    type date_lag_x  \
# 0     2015-01-30  AAA   5.94  39.599998  2.352240e+05  midCap 2014-08-30
# 1     2015-02-27  AAA   6.22  39.599998  2.463120e+05  midCap 2014-09-27
# 2     2015-03-31  AAA   5.76  39.599998  2.280960e+05  midCap 2014-10-31
# 3     2015-04-27  AAA   5.94  39.599998  2.352240e+05  midCap 2014-11-27
# 4     2015-05-29  AAA   6.08  39.599998  2.407680e+05  midCap 2014-12-29
# ...          ...  ...    ...        ...           ...     ...        ...
# 10023 2021-03-31  VSC  53.56  55.122799  2.952377e+06  midCap 2020-10-31
# 10024 2021-04-29  VSC  49.50  55.122799  2.728579e+06  midCap 2020-11-29
# 10025 2021-05-31  VSC  51.70  55.122799  2.849849e+06  midCap 2020-12-31
# 10026 2021-06-30  VSC  60.00  55.122799  3.307368e+06  midCap 2021-01-30
# 10027 2021-07-01  VSC  59.60  55.122799  3.285319e+06  midCap 2021-02-01
#
#        year  quarter  total equity  gross profit  total assets        pB  \
# ...

# %%
price_monthly_pivot = price_oi_fin_monthly.pivot(index='date', columns='code', values='close')
monthly_return = price_monthly_pivot/price_monthly_pivot.shift(1)-1

# %%
# monthly_return_6m = monthly_return.rolling(6).mean()
monthly_return_6m = price_monthly_pivot/price_monthly_pivot.shift(6)-1
monthly_return_6m = monthly_return_6m.reset_index()
monthly_return_6m = pd.melt(monthly_return_6m, id_vars=['date'], value_vars=monthly_return_6m.columns[1:])
monthly_return_6m = monthly_return_6m.rename(columns={'value': 'momentum'})
monthly_return_6m
# Out:
#             date code  momentum
# 0     2015-01-30  AAA       NaN
# 1     2015-02-27  AAA       NaN
# 2     2015-03-31  AAA       NaN
# 3     2015-04-27  AAA       NaN
# 4     2015-05-29  AAA       NaN
# ...          ...  ...       ...
# 11292 2021-03-31  VSC  0.539965
# 11293 2021-04-29  VSC  0.219512
# 11294 2021-05-31  VSC  0.086819
# 11295 2021-06-30  VSC  0.099908
# 11296 2021-07-01  VSC  0.032571
#
# [11297 rows x 3 columns]

# %%
price_oi_fin_monthly = pd.merge(price_oi_fin_monthly, monthly_return_6m, on=['code', 'date'], how='left')

# %% [markdown]
# # Filter by Group

# %%
price_oi_fin_monthly_filtered = price_oi_fin_monthly[(price_oi_fin_monthly['type']!='')]

# %% [markdown]
# # Continue

# %%
price_oi_fin_monthly_filtered
# Out:
#             date code  close         oi        marcap    type date_lag_x  \
# 0     2015-01-30  AAA   5.94  39.599998  2.352240e+05  midCap 2014-08-30
# 1     2015-02-27  AAA   6.22  39.599998  2.463120e+05  midCap 2014-09-27
# 2     2015-03-31  AAA   5.76  39.599998  2.280960e+05  midCap 2014-10-31
# 3     2015-04-27  AAA   5.94  39.599998  2.352240e+05  midCap 2014-11-27
# 4     2015-05-29  AAA   6.08  39.599998  2.407680e+05  midCap 2014-12-29
# ...          ...  ...    ...        ...           ...     ...        ...
# 10023 2021-03-31  VSC  53.56  55.122799  2.952377e+06  midCap 2020-10-31
# 10024 2021-04-29  VSC  49.50  55.122799  2.728579e+06  midCap 2020-11-29
# 10025 2021-05-31  VSC  51.70  55.122799  2.849849e+06  midCap 2020-12-31
# 10026 2021-06-30  VSC  60.00  55.122799  3.307368e+06  midCap 2021-01-30
# 10027 2021-07-01  VSC  59.60  55.122799  3.285319e+06  midCap 2021-02-01
#
#        year  quarter  total equity  gross profit  total assets        pB  \
# ...

# %%
pB = pd.pivot(price_oi_fin_monthly_filtered, 
              index='date', columns='code', values='pB').dropna(how='all', axis=1)
momentum = pd.pivot(price_oi_fin_monthly_filtered, 
                    index='date', columns='code', values='momentum').dropna(how='all', axis=1)

# %%
gPtoA = pd.pivot(price_oi_fin_monthly_filtered, 
                 index='date', 
                 columns='code', 
                 values='grossProfit/assets').dropna(how='all', axis=1)
# gPtoA = gPtoA*price_avg_value_monthly

# %%
pB_ranking = pB.copy(deep=True)
gPtoA_ranking = gPtoA.copy(deep=True)
momentum_ranking = momentum.copy(deep=True)

for col in pB_ranking.columns:
    pB_ranking[col] = np.nan
    gPtoA_ranking[col] = np.nan
    momentum_ranking[col] = np.nan

# %%
pB_ranking = pB.rank(axis=1, ascending=False)
gPtoA_ranking = gPtoA.rank(axis=1, ascending = False)
momentum_ranking = momentum.rank(axis=1, ascending = False)

# %%
gPtoA_ranking
# Out:
# code         AAA    AMD   ANV   APG   ASM   AST    BCG    BID   BMP   BWE  \
# date
# 2015-01-30  32.0   66.0  39.0  69.0  53.0   NaN    NaN   84.0   7.0   NaN
# 2015-02-27  32.0   66.0  39.0  69.0  53.0   NaN    NaN   84.0   7.0   NaN
# 2015-03-31  59.0   77.0  39.0  16.0  31.0   NaN    NaN   83.0  10.0   NaN
# 2015-04-27  59.0   77.0  39.0  16.0  31.0   NaN    NaN   83.0  10.0   NaN
# 2015-05-29  59.0   77.0  39.0  16.0  31.0   NaN    NaN   83.0  10.0   NaN
# ...          ...    ...   ...   ...   ...   ...    ...    ...   ...   ...
# 2021-03-31  83.0  111.0  66.0  43.0  89.0  62.0  129.0  125.0  10.0  55.0
# 2021-04-29  83.0  111.0  66.0  43.0  89.0  62.0  129.0  125.0  10.0  55.0
# 2021-05-31  83.0  111.0  66.0  43.0  89.0  62.0  129.0  125.0  10.0  55.0
# 2021-06-30  68.0  116.0  61.0  63.0  86.0  64.0  117.0  118.0  18.0  53.0
# 2021-07-01  68.0  116.0  61.0  63.0  86.0  64.0  117.0  118.0  18.0  53.0
#
# ...

# %%
combined_ranks = (pB_ranking + gPtoA_ranking + momentum_ranking)/3
# combined_ranks = (pB_ranking + gPtoA_ranking)/2
combined_ranks = combined_ranks.rank(axis=1, ascending=True)

# %%
### CHECK PERFORMANCE OF THE TOP OF SPECIFIC STOCKS (TOP 15 STOCKS, 10 STOCKS, ...)

positions = monthly_return.copy(deep=True)
for col in positions.columns:
    positions[col] = np.nan

# %%
for col in positions.columns:
    if col in combined_ranks.columns:
        positions[col] = combined_ranks[col].apply(lambda x: 1 if x<=7 else np.nan)
    else:
        positions = positions.drop(columns=col)
        
profit = monthly_return * positions.shift(1)

profit['avgProfit'] = profit.mean(axis=1)

profit=profit.reset_index()
profit = profit[profit['date']>'2016-03-31']
profit=profit.set_index('date')

profit['cumulative'] = (profit['avgProfit'] + 1).cumprod()

profit['numHolding'] = profit.count(axis=1)

profit
# Out:
# code        AAA  AMD  ANV       APG       ASM  AST  BCG  BID  BMP  BWE  ...  \
# date                                                                    ...
# 2016-04-29  NaN  NaN  NaN  0.017817       NaN  NaN  NaN  NaN  NaN  NaN  ...
# 2016-05-31  NaN  NaN  NaN  0.378556       NaN  NaN  NaN  NaN  NaN  NaN  ...
# 2016-06-30  NaN  NaN  NaN  0.000000       NaN  NaN  NaN  NaN  NaN  NaN  ...
# 2016-07-29  NaN  NaN  NaN       NaN       NaN  NaN  NaN  NaN  NaN  NaN  ...
# 2016-08-31  NaN  NaN  NaN       NaN       NaN  NaN  NaN  NaN  NaN  NaN  ...
# ...         ...  ...  ...       ...       ...  ...  ...  ...  ...  ...  ...
# 2021-03-31  NaN  NaN  NaN       NaN -0.019417  NaN  NaN  NaN  NaN  NaN  ...
# 2021-04-29  NaN  NaN  NaN       NaN       NaN  NaN  NaN  NaN  NaN  NaN  ...
# 2021-05-31  NaN  NaN  NaN       NaN       NaN  NaN  NaN  NaN  NaN  NaN  ...
# 2021-06-30  NaN  NaN  NaN       NaN       NaN  NaN  NaN  NaN  NaN  NaN  ...
# ...

# %%
a= combined_ranks.reset_index()
a = a.melt(id_vars=['date'], value_vars=a.columns[1:])
a[a['date']=='2021-07-01'][a['value']<=7]
# Out:
# C:\Users\ADMIN\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#             date code  value
# 2448  2021-07-01  DLG    5.0
# 2527  2021-07-01  DPG    1.0
# 2606  2021-07-01  DPM    7.0
# 4107  2021-07-01  HAX    6.0
# 6793  2021-07-01  NKG    2.5
# 8689  2021-07-01  SHI    4.0
# 11059 2021-07-01  VPG    2.5

# %%
a
# Out:
#             date code  value
# 0     2015-01-30  AAA    NaN
# 1     2015-02-27  AAA    NaN
# 2     2015-03-31  AAA    NaN
# 3     2015-04-27  AAA    NaN
# 4     2015-05-29  AAA    NaN
# ...          ...  ...    ...
# 11292 2021-03-31  VSC   14.5
# 11293 2021-04-29  VSC   49.5
# 11294 2021-05-31  VSC   43.5
# 11295 2021-06-30  VSC   38.5
# 11296 2021-07-01  VSC   63.0
#
# [11297 rows x 3 columns]

# %%
b = profit.reset_index()
b=b.melt(id_vars=['date'], value_vars=b.columns[1:-3])
b[b['date']=='2021-07-01'].dropna()
# Out:
#            date code     value
# 1983 2021-07-01  DLG  0.032258
# 2303 2021-07-01  DXG -0.008333
# 3327 2021-07-01  HAX  0.012821
# 5503 2021-07-01  NKG  0.025352
# 7039 2021-07-01  SHI -0.003899
# 8191 2021-07-01  TVB  0.046053
# 8959 2021-07-01  VPG  0.013453

# %%
momentum[['AAA', 'VSC']]

# %%
import plotly.graph_objects as go
cumulative = profit['cumulative'].to_list()

monthly_return = monthly_return.reset_index()
monthly_return = monthly_return[monthly_return['date']>'2016-03-31']
monthly_return = monthly_return.set_index('date')
benchmark = (monthly_return.mean(axis=1)+ 1).cumprod().tolist()
fig = go.Figure()
fig.add_trace(
    go.Scatter(x=profit.index.tolist(), y=cumulative,
               mode='lines',
               name='cumulative'))
fig.add_trace(
    go.Scatter(x=profit.index.tolist(), y=benchmark,
               mode='lines',
               name='benchmark'))

fig.show()

# %%
pos = positions.reset_index()
pos = pd.melt(pos, id_vars='date', value_vars=pos.columns[1:])
pos[(pos['date']=='2021-03-31')&(pos['value'].isna()==False)]

# %% [markdown]
# # CHECK PERFORMANCE OF THE TOP BY % (TOP 10%, 20%,...)

# %%
combined_ranks['count'] = combined_ranks.count(axis='columns')

for col in combined_ranks.columns[:-1]:
    combined_ranks[col] = combined_ranks[col]/combined_ranks['count']

# %%
combined_ranks

# %%
# CHECK PERFORMANCE OF THE TOP BY % (TOP 10%, 20%,...)

lst_rank = [10]

result = positions.reset_index()[['date']].set_index('date')

for r in lst_rank:
    positions = monthly_return.copy(deep=True)
    for col in positions.columns:
        positions[col] = np.nan
    profit = positions.copy(deep=True)
    for col in positions.columns:
        if col in combined_ranks.columns:
            positions[col] = combined_ranks[col].apply(lambda x: 1 if x<=r*0.01 else np.nan)
        else:
            positions = positions.drop(columns=col)
    profit = monthly_return * positions.shift(1)
    profit['avgProfit'] = profit.mean(axis=1)
    profit['numHolding'] = profit.count(axis=1)
    
    result[str(r)] = profit['avgProfit']
    
    
    print('Top {}'.format(str(r)))
    print(profit['numHolding'].max())
    
for r in lst_rank:
    if r > 10:
        result['avgProfit'+ str(r)] = result[str(r)]*r/10 - result[str(r-10)]*(r-10)/10
    else:
        result['avgProfit'+ str(r)] = result[str(r)]
    
    result['cumulative' + str(r)] = (result['avgProfit'+ str(r)]+1).cumprod()
        
#     print('Top {} === Profit {} === Max Holding {}'.format(str(r*10), ))

# profit

import plotly.graph_objects as go

benchmark = (monthly_return.mean(axis=1)+ 1).cumprod().tolist()
fig = go.Figure()

for r in lst_rank:
    cumulative = result['cumulative'+ str(r)].to_list()
    fig.add_trace(
        go.Scatter(x=profit.index.tolist(), y=cumulative,
                   mode='lines',
                   name='cumulative'+ str(r)))
fig.add_trace(
    go.Scatter(x=profit.index.tolist(), y=benchmark,
               mode='lines',
               name='benchmark'))

fig.show()

# %%
a = positions[-1:].transpose()
a.columns = ['a']
a[a['a']==1]

# %%
pos = positions.transpose()
pos = pos['2021-04-29'].reset_index()
pos.columns.values[1] = '2021-04-29'
# pos
pos[pos['2021-04-29'].isna()==False].to_csv('2021-04-29-implement.csv', index=None)

# %%
positions
